# %% [markdown]
# ### How are in-demand skills trending for Data Analyst?
#
# Methodology:
# 1. Aggregate skill counts monthly
# 2. Re-analyze based on percentage of total jobs
# 3. Plot the monthly skill demand

# %%
# Importing Libraries
import ast
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt
import seaborn as sns

# Loading Data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# Data Cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])
df['job_skills'] = df['job_skills'].apply(lambda x: ast.literal_eval(x) if pd.notna(x) else x)

# %%
df_DA_US = df[(df['job_title_short'] == 'Data Analyst') & (df['job_country'] == 'United States')].copy()
df_DA_US
# Out:
#        job_title_short                                     job_title  \
# 36        Data Analyst                                  Data Analyst
# 68        Data Analyst                     Sr. Research Data Analyst
# 73        Data Analyst   Entry level / Systems Data Analyst (Remote)
# 79        Data Analyst                    Data Analyst/Report Writer
# 93        Data Analyst  IT Finance / TBM Data Analyst - Remote | WFH
# ...                ...                                           ...
# 785603    Data Analyst                           Junior Data Analyst
# 785626    Data Analyst                    Data Acquisition Associate
# 785685    Data Analyst                                  Data Analyst
# 785703    Data Analyst       Data Analyst - CRYPTOGRAPHY - Full-time
# 785705    Data Analyst     Expert Business Data Analyst - Now Hiring
#
#             job_location               job_via job_schedule_type  \
# 36        Des Moines, IA       via Trabajo.org         Full-time
# ...

# %%
months_order = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun',
                'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']

df_DA_US['job_posted_month'] = df_DA_US['job_posted_date'].dt.strftime('%b')

df_DA_US['job_posted_month'] = pd.Categorical(
    df_DA_US['job_posted_month'],
    categories=months_order,
    ordered=True
)

df_DA_US['job_posted_month']
# Out:
# 36        Nov
# 68        Mar
# 73        Jun
# 79        Aug
# 93        Jun
#          ...
# 785603    Sep
# 785626    Oct
# 785685    Jul
# 785703    Jan
# 785705    Jan
# Name: job_posted_month, Length: 67816, dtype: category
# Categories (12, object): ['Jan' < 'Feb' < 'Mar' < 'Apr' ... 'Sep' < 'Oct' < 'Nov' < 'Dec']

# %%
df_DA_US_explode = df_DA_US.explode('job_skills').copy()
df_DA_US_explode
# Out:
#        job_title_short                                    job_title  \
# 36        Data Analyst                                 Data Analyst
# 68        Data Analyst                    Sr. Research Data Analyst
# 68        Data Analyst                    Sr. Research Data Analyst
# 73        Data Analyst  Entry level / Systems Data Analyst (Remote)
# 73        Data Analyst  Entry level / Systems Data Analyst (Remote)
# ...                ...                                          ...
# 785685    Data Analyst                                 Data Analyst
# 785703    Data Analyst      Data Analyst - CRYPTOGRAPHY - Full-time
# 785705    Data Analyst    Expert Business Data Analyst - Now Hiring
# 785705    Data Analyst    Expert Business Data Analyst - Now Hiring
# 785705    Data Analyst    Expert Business Data Analyst - Now Hiring
#
#             job_location           job_via job_schedule_type  \
# 36        Des Moines, IA   via Trabajo.org         Full-time
# ...

# %%
df_DA_US_pivot = df_DA_US_explode.pivot_table(
    index='job_posted_month',
    columns='job_skills',
    aggfunc='size',
    fill_value=0,
    observed=False
).copy()

df_DA_US_pivot
# Out:
# job_skills        airflow  airtable  alteryx  angular  ansible  apl  arch  \
# job_posted_month
# Jan                    39         7      206       21        7    1     0
# Feb                    35         0      203       23        4    1     0
# Mar                    39         1      219        5        5    6     1
# Apr                    28         1      208        8        3    7     3
# May                    27         3      144       15        8    9     1
# Jun                    39         5      188        9        4    8     3
# Jul                    42         2      160        5        3    5     5
# Aug                    44         2      187        5        3   10     0
# Sep                    22         3      145       11        2    3     4
# Oct                    29         9      144       13        2    0     3
# Nov                    23         1      126        4        2    0     1
# ...

# %%
df_DA_US_pivot.loc['Total'] = df_DA_US_pivot.sum()
df_DA_US_pivot
# Out:
# job_skills        airflow  airtable  alteryx  angular  ansible  apl  arch  \
# job_posted_month
# Jan                    39         7      206       21        7    1     0
# Feb                    35         0      203       23        4    1     0
# Mar                    39         1      219        5        5    6     1
# Apr                    28         1      208        8        3    7     3
# May                    27         3      144       15        8    9     1
# Jun                    39         5      188        9        4    8     3
# Jul                    42         2      160        5        3    5     5
# Aug                    44         2      187        5        3   10     0
# Sep                    22         3      145       11        2    3     4
# Oct                    29         9      144       13        2    0     3
# Nov                    23         1      126        4        2    0     1
# ...

# %%
df_DA_US_pivot = df_DA_US_pivot[
    df_DA_US_pivot.loc['Total']
    .sort_values(ascending=False)
    .index
].copy()

df_DA_US_pivot.drop(labels='Total', inplace=True)

df_DA_US_pivot
# Out:
# job_skills         sql  excel  tableau  python   sas     r  power bi  word  \
# job_posted_month
# Jan               4601   3592     2488    2254  1832  1513      1337   968
# Feb               3168   2587     1676    1618  1212  1045      1122   738
# Mar               3226   2661     1804    1683  1238  1141      1054   736
# Apr               3220   2549     1789    1679  1302  1038      1057   695
# May               2581   2118     1432    1349   972   867       860   557
# Jun               2862   2382     1628    1609   984  1017       989   721
# Jul               2609   2118     1533    1438   996   881       881   587
# Aug               3414   2731     1951    2025  1276  1271      1208   752
# Sep               2295   1801     1353    1229   856   746       820   478
# Oct               2574   1922     1429    1373   960   835       921   498
# Nov               2054   1533     1148    1049   792   647       682   430
# ...

# %%
DA_totals = df_DA_US.groupby('job_posted_month', observed=False).size().copy()
DA_totals
# Out:
# job_posted_month
# Jan    8494
# Feb    6124
# Mar    6218
# Apr    6049
# May    4993
# Jun    5683
# Jul    5201
# Aug    6634
# Sep    4639
# Oct    5271
# Nov    4531
# Dec    3979
# dtype: int64

# %%
df_DA_US_percent = df_DA_US_pivot.div(DA_totals / 100, axis=0).copy()
df_DA_US_percent
# Out:
# job_skills              sql      excel    tableau     python        sas  \
# job_posted_month
# Jan               54.167648  42.288674  29.291264  26.536379  21.568166
# Feb               51.730895  42.243632  27.367734  26.420640  19.790986
# Mar               51.881634  42.795111  29.012544  27.066581  19.909939
# Apr               53.231939  42.139197  29.575136  27.756654  21.524219
# May               51.692369  42.419387  28.680152  27.017825  19.467254
# Jun               50.360725  41.914482  28.646841  28.312511  17.314799
# Jul               50.163430  40.722938  29.475101  27.648529  19.150163
# Aug               51.462165  41.166717  29.409105  30.524570  19.234248
# Sep               49.471869  38.823022  29.165768  26.492779  18.452253
# Oct               48.833238  36.463669  27.110605  26.048188  18.212863
# Nov               45.332156  33.833591  25.336570  23.151622  17.479585
# Dec               46.443830  38.326213  27.142498  27.041970  19.602915
#
# ...

# %%
df_plot = df_DA_US_percent.iloc[:,:5].copy()
df_plot
# Out:
# job_skills              sql      excel    tableau     python        sas
# job_posted_month
# Jan               54.167648  42.288674  29.291264  26.536379  21.568166
# Feb               51.730895  42.243632  27.367734  26.420640  19.790986
# Mar               51.881634  42.795111  29.012544  27.066581  19.909939
# Apr               53.231939  42.139197  29.575136  27.756654  21.524219
# May               51.692369  42.419387  28.680152  27.017825  19.467254
# Jun               50.360725  41.914482  28.646841  28.312511  17.314799
# Jul               50.163430  40.722938  29.475101  27.648529  19.150163
# Aug               51.462165  41.166717  29.409105  30.524570  19.234248
# Sep               49.471869  38.823022  29.165768  26.492779  18.452253
# Oct               48.833238  36.463669  27.110605  26.048188  18.212863
# Nov               45.332156  33.833591  25.336570  23.151622  17.479585
# Dec               46.443830  38.326213  27.142498  27.041970  19.602915

# %%
from matplotlib.ticker import PercentFormatter

sns.set_theme(style='ticks')
plt.figure(figsize=(10, 6))

# Plot the lines
sns.lineplot(data=df_plot, dashes=False, palette='tab10')
sns.despine()

# Annotate each line
for skill in df_plot.columns:
    x = df_plot.index[-1]
    y = df_plot[skill].iloc[-1]

    plt.text(
        x=x,
        y=y + 0.5,  # Nudge up
        s=skill,
        fontsize=9,
        va='center',
        ha='left',
        fontweight='bold'
    )

# Move the legend outside the plot to the right
plt.legend(
    title='Skills',
    bbox_to_anchor=(1.02, 1),
    loc='upper left',
    borderaxespad=0
)

plt.gca().yaxis.set_major_formatter(PercentFormatter(decimals=0))

# Labels and layout
plt.title("Trending Top Skills for Data Analysis in US")
plt.xlabel("2023")
plt.ylabel("Job Postings (by Percentage)")
plt.tight_layout()
plt.show()
